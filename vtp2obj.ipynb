# %%
import pyvista as pv
# reader = pv.get_reader('cifar10/models/resnet56_sgd_lr=0.1_bs=128_wd=0.0005/model_300.t7_weights_xignore=biasbn_xnorm=filter_yignore=biasbn_ynorm=filter.h5_[-1.0,1.0,51]x[-1.0,1.0,51].h5_train_loss.vtp')
reader = pv.get_reader('loss-landscape/cifar10/models/resnet56_sgd_lr=0.1_bs=128_wd=0.0005/model_300.t7_weights_xignore=biasbn_xnorm=filter_yignore=biasbn_ynorm=filter.h5_[-1.0,1.0,51]x[-1.0,1.0,51].h5_train_loss_log.vtp')
reader
# Out:
# XMLPolyDataReader('loss-landscape/cifar10/models/resnet56_sgd_lr=0.1_bs=128_wd=0.0005/model_300.t7_weights_xignore=biasbn_xnorm=filter_yignore=biasbn_ynorm=filter.h5_[-1.0,1.0,51]x[-1.0,1.0,51].h5_train_loss_log.vtp')

# %%
mesh = reader.read()

# %%
pl = pv.Plotter()
pl.add_mesh(mesh, scalars="zvalue", cmap="viridis")
pl.show()
# Out:
# /Users/famousamoscookie/loss-landscapes-lens/.venv/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:37: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
mesh.point_data["zvalue"]
# Out:
# pyvista_ndarray([2.8555562, 2.693323 , 2.5711613, ..., 2.232064 ,
#                  2.379725 , 2.5482607], dtype=float32)

# %%
pl.export_obj('resnet56.obj')
